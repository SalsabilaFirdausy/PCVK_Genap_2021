# %% [markdown]
# <a href="https://colab.research.google.com/github/SalsabilaFirdausy/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


# Accessing My Google Drive
drive.mount('/content/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g5B3bmnRCvI-sBSKvzUdwDCZ-pRcP5-yeB1D_MKAowCvjY9rz03BIA
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten.jpg')
plt.imshow(img)

# %%
mg2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #Konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))   #ubah ukuran(10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))  #nilai 2 menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#Assignment 1
img2 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
plt.imshow(img2)

# %%
#Assignment2
plt.imshow(img_gray, cmap='RdYlGn'),plt.title("Red-Green")
# Out:
# (<matplotlib.image.AxesImage at 0x7f1b2acf54a8>, Text(0.5, 1.0, 'Red-Green'))

# %%
#Assignment3
plt.imshow(img_gray, cmap='GnBu'),plt.title("Green-Blue")
# Out:
# (<matplotlib.image.AxesImage at 0x7f1b2acde2e8>, Text(0.5, 1.0, 'Green-Blue'))

# %%
#Assignment 3
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %%
#Assignment 4
plt.imshow(img5[5:30])

# %%
#Assignment 5
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range (6):
  start = random.randint(0,400)
  end = random.randint(0,400)

  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)

  pointstart = (start,start)
  pointend = (end, end)
  color = (c1, c2, c3)
  thickness = 2
  img6 = cv.rectangle(img3, pointstart, pointend, color, thickness)

plt.imshow(img6)

# %%
#Assignment 6
img6 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))   
ax = fig.add_subplot(111)
ax.imshow(img6)

# %%
#Assignment 7,8,9
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111)

cv.rectangle(img5, pt1=(500,100), pt2=(300,300), color=(0,255,0), thickness=2)
cv.circle(img5, center=(410,250), radius=100, color=(255,0,0), thickness=2)
cv.rectangle(img5, pt1=(50,600), pt2=(350,550), color=(0,0,255), thickness=2)
cv.putText(img5, text='SalsabilaFirdausy', org=(60,580), fontFace=font, fontScale=1, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)

ax.imshow(img5)
